# %%
import pandas as pd

# %%
! pip install pandas openpyxl

# %%
! ls
# Out:
# cambodia.xlsx  co1-laos.fa  cytb-camb.fa  cytob-vn.fa  nb.ipynb
# co1-camb.fa    co1-vn.fa    cytb-laos.fa  laos.xlsx    vn.xlsx

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel("vn.xlsx", engine="openpyxl")
df
# Out:
#                    Tên thông thường               Tên khoa học  \
# 0                Chồn bay (Cầy bay)     Galeopterus variegatus
# 1                      Dơi ngựa lớn          Pteropus vampyrus
# 2                         Cu li lớn     Nycticebus bengalensis
# 3                         Cu li nhỏ        Nycticebus pygmaeus
# 4              Voọc chà vá chân xám          Pygathrix cinerea
# ..                              ...                        ...
# 134                    Rùa núi vàng       Indotestudo elongata
# 135                    Rùa núi viền          Manouria impressa
# 136                   Cá sấu hoa cà         Crocodylus porosus
# 137  Cá sấu nước ngọt (Cá sấu Xiêm)       Crocodylus siamensis
# 138                  Cá cóc Tam Đảo  Paramesotriton deloustali
#
#             Tên tiếng Anh            Kiểu gen                  COI  \
# 0      Sunda flying lemur             full mt             AF460846
# 1        Large flying fox             full mt            NC_026542
# ...

# %%
df.head()
# Out:
#        Tên thông thường            Tên khoa học       Tên tiếng Anh  \
# 0    Chồn bay (Cầy bay)  Galeopterus variegatus  Sunda flying lemur
# 1          Dơi ngựa lớn       Pteropus vampyrus    Large flying fox
# 2             Cu li lớn  Nycticebus bengalensis        Bengal loris
# 3             Cu li nhỏ     Nycticebus pygmaeus         Pygmy loris
# 4  Voọc chà vá chân xám       Pygathrix cinerea   Gray-shanked douc
#
#     Kiểu gen               COI       Cytb Phân hạng IUCN (2008 v3.1)  \
# 0    full mt          AF460846   AF460846                         LC
# 1    full mt         NC_026542  NC_026542                         NT
# 2    full mt          KC977312   KC977312          VU A2acd+3cd+4acd
# 3  cytb, COI  KJ862196 barcode  AY687893                     VU A2cd
# 4    full mt         NC_018063  NC_018063            CR A2cd+3cd+4cd
#
#                                     Link IUCN  \
# 0  http://www.iucnredlist.org/details/41502/0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Tên thông thường                       139 non-null    object
#  1   Tên khoa học                           139 non-null    object
#  2   Tên tiếng Anh                          139 non-null    object
#  3   Kiểu gen                               126 non-null    object
#  4   COI                                    86 non-null     object
#  5   Cytb                                   127 non-null    object
#  6   Phân hạng IUCN (2008 v3.1)             133 non-null    object
#  7   Link IUCN                              131 non-null    object
#  8   Phân hạng Danh lục Đỏ Việt Nam (2007)  113 non-null    object
#  9   Mô tả                                  100 non-null    object
# ...
